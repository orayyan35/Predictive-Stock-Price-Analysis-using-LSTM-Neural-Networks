# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas_datareader.data import DataReader
import yfinance as yf
from pandas_datareader import data as pdr
from datetime import datetime
import plotly.express as px
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-03-22  177.750000  179.259995  176.750000  178.869995  178.869995
# 2024-03-25  178.009995  180.990005  177.240005  179.710007  179.710007
# 2024-03-26  180.149994  180.449997  177.949997  178.300003  178.300003
# 2024-03-27  179.880005  180.000000  177.309998  179.830002  179.830002
# 2024-03-28  180.169998  181.699997  179.259995  180.380005  180.380005
# 2024-04-01  180.789993  183.000000  179.949997  180.970001  180.970001
# 2024-04-02  179.070007  180.789993  178.380005  180.690002  180.690002
# 2024-04-03  179.899994  182.869995  179.800003  182.410004  182.410004
# ...

# %%
# sns.set_style('whitegrid')
# plt.style.use("fivethirtyeight")
# %matplotlib inline

# yf.pdr_override()

# # For time stamps

# # The tech stocks we'll use for this analysis
# tech_list = ['AAPL', 'GOOG', 'MSFT', 'AMZN']

# # Set up End and Start times for data grab
# end = datetime.now()
# start = datetime(end.year - 1, end.month, end.day)

# # Fetching data for each stock in the tech list
# company_list = []
# company_name = []

# for stock in tech_list:
#     data = yf.download(stock, start, end)
#     data['company_name'] = stock  # Adding a column for company name
#     company_list.append(data)
#     company_name.append(stock)

# # Concatenating the data of all companies into a single DataFrame
# df = pd.concat(company_list, axis=0)

# # Displaying the tail of the DataFrame
# df.tail(10)
# Out:
# Index(['Date', ' Close/Last', ' Volume', ' Open', ' High', ' Low'], dtype='object')

# %%
# !pip install pandas_datareader
# Out:
# ...
#   Obtaining dependency information for pandas_datareader from https://files.pythonhosted.org/packages/3f/16/56c9d648b503619ebe96f726b5f642b68e299b34162ed2d6faa9d7966b7d/pandas_datareader-0.10.0-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 kB 1.0 MB/s eta 0:00:00 0:00:01
# ...

# %%
# !pip install yfinance
# Out:
# ...
#   Obtaining dependency information for yfinance from https://files.pythonhosted.org/packages/14/03/3c854ca3e02eedf614abba4b2e177c469bf3af58207fa30d5098c5d652fe/yfinance-0.2.37-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for multitasking>=0.0.7 from https://files.pythonhosted.org/packages/3e/8a/bb3160e76e844db9e69a413f055818969c8acade64e1a9ac5ce9dfdcf6c1/multitasking-0.0.11-py3-none-any.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.2/315.2 kB 1.9 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 9.8 MB/s eta 0:00:00:00:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
df1 =df

# %% [markdown]
# ---

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1004 entries, 2023-04-06 to 2024-04-05
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          1004 non-null   float64
#  1   High          1004 non-null   float64
#  2   Low           1004 non-null   float64
#  3   Close         1004 non-null   float64
#  4   Adj Close     1004 non-null   float64
#  5   Volume        1004 non-null   int64
#  6   company_name  1004 non-null   object
# dtypes: float64(5), int64(1), object(1)
# memory usage: 62.8+ KB

# %%
df.isna().sum()
# Out:
# Open            0
# High            0
# Low             0
# Close           0
# Adj Close       0
# Volume          0
# company_name    0
# dtype: int64

# %% [markdown]
# # there is no missing data

# %% [markdown]
# ---

# %%
df['Price_Difference'] = df['High'] - df['Low']
df['Percentage_Range'] = ((df['High'] - df['Low']) / df['Low']) * 100

# %% [markdown]
# ---

# %% [markdown]
# plot data

# %%
df["Open"]
# Out:
# Date
# 2023-04-06    162.429993
# 2023-04-10    161.419998
# 2023-04-11    162.350006
# 2023-04-12    161.220001
# 2023-04-13    161.630005
#                  ...
# 2024-04-01    180.789993
# 2024-04-02    179.070007
# 2024-04-03    179.899994
# 2024-04-04    184.000000
# 2024-04-05    182.380005
# Name: Open, Length: 1004, dtype: float64

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(12, 8))
sns.lineplot(data=df, x=df.index, y='Close', hue='company_name')
plt.title('Stock Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend(title='Company', loc='upper left', labels=company_name)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /Users/baker/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/baker/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import plotly.express as px
fig = px.line(df, x='Date', y='Volume', color='company_name', title='Stock Prices Over Time', labels={'Date': 'Date', 'Volume': 'Close Price', 'company_name': 'Company'})
fig.show()
# Out:
# /Users/baker/anaconda3/lib/python3.11/site-packages/_plotly_utils/basevalidators.py:106: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
# ...

# %%
import plotly.express as px
fig = px.line(df, x='Date', y='Adj Close', color='company_name', title='Stock Prices Over Time', labels={'Date': 'Date', 'Adj Close': 'Close Price', 'company_name': 'Company'})
fig.show()
# Out:
# /Users/baker/anaconda3/lib/python3.11/site-packages/_plotly_utils/basevalidators.py:106: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
# ...

# %%
company_values = df.groupby('company_name')['Close'].mean().reset_index()
def plot_company_value(company_name):
    plt.figure(figsize=(10, 6))
    plt.plot(df[df['company_name'] == company_name]['Date'], 
             df[df['company_name'] == company_name]['Close'])
    plt.title('Stock Prices for {}'.format(company_name))
    plt.xlabel('Date')
    plt.ylabel('Close Value')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Check the level of change

# %%
df["company_name"].unique()
# Out:
# array(['APPLE', 'GOOGLE', 'MICROSOFT', 'AMAZON'], dtype=object)

# %% [markdown]
# ----

# %%
df[df['company_name'] == 'AMAZON']
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 753  2023-04-06  100.750000  102.379997   99.800003  102.059998  102.059998
# 754  2023-04-10  100.959999  102.199997   99.570000  102.169998  102.169998
# 755  2023-04-11  100.800003  101.000000   99.010002   99.919998   99.919998
# 756  2023-04-12  100.400002  100.510002   97.709999   97.830002   97.830002
# 757  2023-04-13   98.949997  102.570000   98.709999  102.400002  102.400002
# ...         ...         ...         ...         ...         ...         ...
# 999  2024-04-01  180.789993  183.000000  179.949997  180.970001  180.970001
# 1000 2024-04-02  179.070007  180.789993  178.380005  180.690002  180.690002
# 1001 2024-04-03  179.899994  182.869995  179.800003  182.410004  182.410004
# 1002 2024-04-04  184.000000  185.100006  180.000000  180.000000  180.000000
# 1003 2024-04-05  182.380005  186.270004  181.970001  185.070007  185.070007
#
#         Volume company_name
# ...

# %%
# # df = df.drop("index" , axis = 1 )
# df = df.drop("level_0" , axis = 1 )

# %% [markdown]
# ---

# %%
plot_company_value(selected_company)

# %% [markdown]
# ### We note that there is a strong relationship between the name and the value of the stock The slope of the curve is positive

# %% [markdown]
# ---

# %%
selected_company = "GOOGLE"
plot_company_value(selected_company)

# %% [markdown]
# ---

# %% [markdown]
# ### We note that there is a strong relationship between the name and the value of the stockThe slope of the curve is positive, but it changes a lot. This indicates that a stock changes its value a lot

# %%
selected_company = "MICROSOFT"
plot_company_value(selected_company)

# %% [markdown]
# ### MICROSOFT stock is the strongest and the speed of its price rise is amazing

# %% [markdown]
# ---

# %%
selected_company = "APPLE"
plot_company_value(selected_company)

# %% [markdown]
# ### It is a stock that has specific periods for its value to rise.

# %% [markdown]
# ### We note that the safest stock and the best stock is "Microsoft" stock, and the most dangerous stock is "Apple" stock.

# %% [markdown]
# -----

# %% [markdown]
# ## Relationship between Data and Low Prices and name company

# %%
company_list = df['company_name'].unique()

# %%
data_company = df[df['company_name'] == company_list[0]]

plt.figure(figsize=(10, 6))
plt.scatter(data_company['Date'], data_company['Low'], color='blue', label='Low Prices')
plt.xlabel('Data')
plt.ylabel('Low Prices')
plt.title('Relationship between Data and Low Prices for {}'.format(company_list[0]))
plt.legend()
plt.show()

# %%
data_company = df[df['company_name'] == company_list[1]]

plt.figure(figsize=(10, 6))
plt.scatter(data_company['Date'], data_company['Low'], color='blue', label='Low Prices')
plt.xlabel('Data')
plt.ylabel('Low Prices')
plt.title('Relationship between Data and Low Prices for {}'.format(company_list[0]))
plt.legend()
plt.show()

# %%
data_company = df[df['company_name'] == company_list[2]]

plt.figure(figsize=(10, 6))
plt.scatter(data_company['Date'], data_company['Low'], color='blue', label='Low Prices')
plt.xlabel('Data')
plt.ylabel('Low Prices')
plt.title('Relationship between Data and Low Prices for {}'.format(company_list[0]))
plt.legend()
plt.show()

# %%
data_company = df[df['company_name'] == company_list[3]]

plt.figure(figsize=(10, 6))
plt.scatter(data_company['Date'], data_company['Low'], color='blue', label='Low Prices')
plt.xlabel('Data')
plt.ylabel('Low Prices')
plt.title('Relationship between Data and Low Prices for {}'.format(company_list[0]))
plt.legend()
plt.show()

# %% [markdown]
# ----

# %% [markdown]
# # APPLE:-

# %%
# Out:
# /Users/baker/anaconda3/lib/python3.11/site-packages/_plotly_utils/basevalidators.py:106: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
# ...

# %%
company_data = df[df['company_name'] == companies[0]]
dates = company_data['Date']
prices = company_data['Close']
min_low_price = company_data['Low'].min()
max_low_price = company_data['Low'].max()
min_high_price = company_data['High'].min()
max_high_price = company_data['High'].max()
plt.figure(figsize=(10, 6))
plt.plot(dates, prices, marker='o', linestyle='-', color='b')
plt.title(f'Price Change Over Time for {companies[0]}')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.bar(min_price_date, min_low_price, color='blue', label=f'Min Low: {min_low_price:.2f}')
plt.bar(max_price_date, max_low_price, color='red', label=f'Max Low: {max_low_price:.2f}')
plt.bar(min_price_date, min_high_price, color='blue', label=f'Min High: {min_high_price:.2f}')
plt.bar(max_price_date, max_high_price, color='red', label=f'Max High: {max_high_price:.2f}')
plt.scatter(min_price_date, min_low_price, color='blue', marker='o')
plt.scatter(max_price_date, max_low_price, color='red', marker='o')
plt.scatter(min_price_date, min_high_price, color='blue', marker='o')
plt.scatter(max_price_date, max_high_price, color='red', marker='o')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# From April 2023, the stock prices were recorded. The lowest price during a downturn was 159.78, and the highest price during that downturn was 197.00. We obtained the lowest price during an upturn, which reached 162.03, and the highest price was 199.62.

# %% [markdown]
# ---

# %% [markdown]
# # GOOGLE :-

# %% [markdown]
# ---

# %%
company_list = df['company_name'].unique()
data_company = df[df['company_name'] == company_list[1]]
fig = px.scatter(data_company, x='Date', y='Low', title='Relationship between Data and Low Prices for {}'.format(company_list[1]),
                     labels={'Data': 'Date', 'Low': 'Low Prices'})
fig.show()


company_list = df['company_name'].unique()
data_company = df[df['company_name'] == company_list[1]]
fig = px.scatter(data_company, x='Date', y='High', title='Relationship between Data and High Prices for {}'.format(company_list[1]),
                     labels={'Data': 'Date', 'High': 'High Prices'})
fig.show()
# Out:
# /Users/baker/anaconda3/lib/python3.11/site-packages/_plotly_utils/basevalidators.py:106: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
# ...

# %%
company_data = df[df['company_name'] == companies[1]]
dates = company_data['Date']
prices = company_data['Close']
min_low_price = company_data['Low'].min()
max_low_price = company_data['Low'].max()
min_high_price = company_data['High'].min()
max_high_price = company_data['High'].max()
plt.figure(figsize=(10, 6))
plt.plot(dates, prices, marker='o', linestyle='-', color='b')
plt.title(f'Price Change Over Time for {companies[1]}')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.bar(min_price_date, min_low_price, color='blue', label=f'Min Low: {min_low_price:.2f}')
plt.bar(max_price_date, max_low_price, color='red', label=f'Max Low: {max_low_price:.2f}')
plt.bar(min_price_date, min_high_price, color='blue', label=f'Min High: {min_high_price:.2f}')
plt.bar(max_price_date, max_high_price, color='red', label=f'Max High: {max_high_price:.2f}')
plt.scatter(min_price_date, min_low_price, color='blue', marker='o')
plt.scatter(max_price_date, max_low_price, color='red', marker='o')
plt.scatter(min_price_date, min_high_price, color='blue', marker='o')
plt.scatter(max_price_date, max_high_price, color='red', marker='o')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# In 2023, stock prices for Google were recorded. During a downturn, the lowest value reached was 103.27, and the highest value during that downturn was 154.13. In an upward trend, the lowest value attained was 105.72, and the highest value reached was 157.00.

# %% [markdown]
# ----

# %%
company_list = df['company_name'].unique()
data_company = df[df['company_name'] == company_list[2]]
fig = px.scatter(data_company, x='Date', y='Low', title='Relationship between Data and Low Prices for {}'.format(company_list[2]),
                     labels={'Data': 'Date', 'Low': 'Low Prices'})
fig.show()


company_list = df['company_name'].unique()
data_company = df[df['company_name'] == company_list[2]]
fig = px.scatter(data_company, x='Date', y='High', title='Relationship between Data and High Prices for {}'.format(company_list[2]),
                     labels={'Data': 'Date', 'High': 'High Prices'})
fig.show()
# Out:
# /Users/baker/anaconda3/lib/python3.11/site-packages/_plotly_utils/basevalidators.py:106: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
# ...

# %%
company_data = df[df['company_name'] == companies[2]]
dates = company_data['Date']
prices = company_data['Close']
min_low_price = company_data['Low'].min()
max_low_price = company_data['Low'].max()
min_high_price = company_data['High'].min()
max_high_price = company_data['High'].max()
plt.figure(figsize=(10, 6))
plt.plot(dates, prices, marker='o', linestyle='-', color='b')
plt.title(f'Price Change Over Time for {companies[2]}')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.bar(min_price_date, min_low_price, color='blue', label=f'Min Low: {min_low_price:.2f}')
plt.bar(max_price_date, max_low_price, color='red', label=f'Max Low: {max_low_price:.2f}')
plt.bar(min_price_date, min_high_price, color='blue', label=f'Min High: {min_high_price:.2f}')
plt.bar(max_price_date, max_high_price, color='red', label=f'Max High: {max_high_price:.2f}')
plt.scatter(min_price_date, min_low_price, color='blue', marker='o')
plt.scatter(max_price_date, max_low_price, color='red', marker='o')
plt.scatter(min_price_date, min_high_price, color='blue', marker='o')
plt.scatter(max_price_date, max_high_price, color='red', marker='o')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# n 2023, stock readings were taken for the company MICROSOFT. In the case of a decline, the lowest value obtained was 275.37, and the highest value was 427.16. In the case of an increase, the lowest value obtained was 281.60, and the highest value was 430.82.

# %% [markdown]
# ---

# %%
company_list = df['company_name'].unique()
data_company = df[df['company_name'] == company_list[3]]
fig = px.scatter(data_company, x='Date', y='Low', title='Relationship between Data and Low Prices for {}'.format(company_list[3]),
                     labels={'Data': 'Date', 'Low': 'Low Prices'})
fig.show()


company_list = df['company_name'].unique()
data_company = df[df['company_name'] == company_list[3]]
fig = px.scatter(data_company, x='Date', y='High', title='Relationship between Data and High Prices for {}'.format(company_list[3]),
                     labels={'Data': 'Date', 'High': 'High Prices'})
fig.show()
# Out:
# /Users/baker/anaconda3/lib/python3.11/site-packages/_plotly_utils/basevalidators.py:106: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
# ...

# %%
company_data = df[df['company_name'] == companies[3]]
dates = company_data['Date']
prices = company_data['Close']
min_low_price = company_data['Low'].min()
max_low_price = company_data['Low'].max()
min_high_price = company_data['High'].min()
max_high_price = company_data['High'].max()
plt.figure(figsize=(10, 6))
plt.plot(dates, prices, marker='o', linestyle='-', color='b')
plt.title(f'Price Change Over Time for {companies[3]}')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.bar(min_price_date, min_low_price, color='blue', label=f'Min Low: {min_low_price:.2f}')
plt.bar(max_price_date, max_low_price, color='red', label=f'Max Low: {max_low_price:.2f}')
plt.bar(min_price_date, min_high_price, color='blue', label=f'Min High: {min_high_price:.2f}')
plt.bar(max_price_date, max_high_price, color='red', label=f'Max High: {max_high_price:.2f}')
plt.scatter(min_price_date, min_low_price, color='blue', marker='x')
plt.scatter(max_price_date, max_low_price, color='red', marker='o')
plt.scatter(min_price_date, min_high_price, color='blue', marker='x')
plt.scatter(max_price_date, max_high_price, color='red', marker='o')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# In 2023, a stock reading was taken for company AMAZON. In a state of decline, the lowest value obtained was 97.71, and the highest value in the decline state was 181.97. In an ascent state, the lowest value obtained was 100.51, and the highest value was 186.2

# %% [markdown]
# ---

# %%
selected_columns = ['Close', 'Open']
sns.pairplot(df[selected_columns], markers='o', diag_kind='kde')
plt.show()
# Out:
# /Users/baker/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# /Users/baker/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# /Users/baker/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight

# %% [markdown]
# # Linear relationship between('Close', 'Open')

# %%
selected_columns = ['High', 'Low']
sns.pairplot(df[selected_columns], markers='o', diag_kind='kde')
plt.show()
# Out:
# /Users/baker/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# /Users/baker/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# /Users/baker/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight

# %% [markdown]
# # Linear relationship between ['High', 'Low']

# %%
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2023-04-06  162.429993  164.960007  162.000000  164.660004  163.785767
# 1    2023-04-10  161.419998  162.029999  160.080002  162.029999  161.169724
# 2    2023-04-11  162.350006  162.360001  160.509995  160.800003  159.946243
# 3    2023-04-12  161.220001  162.059998  159.779999  160.100006  159.249985
# 4    2023-04-13  161.630005  165.800003  161.419998  165.559998  164.680984
# ...         ...         ...         ...         ...         ...         ...
# 999  2024-04-01  180.789993  183.000000  179.949997  180.970001  180.970001
# 1000 2024-04-02  179.070007  180.789993  178.380005  180.690002  180.690002
# 1001 2024-04-03  179.899994  182.869995  179.800003  182.410004  182.410004
# 1002 2024-04-04  184.000000  185.100006  180.000000  180.000000  180.000000
# 1003 2024-04-05  182.380005  186.270004  181.970001  185.070007  185.070007
#
# ...

# %%
selected_columns = ['Close', 'Adj Close']
sns.pairplot(df[selected_columns], markers='o', diag_kind='kde')
plt.show()
# Out:
# /Users/baker/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# /Users/baker/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# /Users/baker/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight

# %% [markdown]
# # Linear relationship between  ['Close', 'Adj Close']

# %% [markdown]
# ---

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Daily_Change'] = df.groupby('company_name')['Close'].diff()
df['Monthly_Change'] = df.groupby(['company_name', df['Date'].dt.month])['Close'].diff()
df['Yearly_Change'] = df.groupby(['company_name', df['Date'].dt.year])['Close'].diff()
# Out:
#            Date company_name  Daily_Change  Monthly_Change  Yearly_Change
# 0    2023-04-06        APPLE           NaN             NaN            NaN
# 1    2023-04-10        APPLE     -2.630005       -2.630005      -2.630005
# 2    2023-04-11        APPLE     -1.229996       -1.229996      -1.229996
# 3    2023-04-12        APPLE     -0.699997       -0.699997      -0.699997
# 4    2023-04-13        APPLE      5.459991        5.459991       5.459991
# ...         ...          ...           ...             ...            ...
# 999  2024-04-01       AMAZON      0.589996       75.520004       0.589996
# 1000 2024-04-02       AMAZON     -0.279999       -0.279999      -0.279999
# 1001 2024-04-03       AMAZON      1.720001        1.720001       1.720001
# 1002 2024-04-04       AMAZON     -2.410004       -2.410004      -2.410004
# 1003 2024-04-05       AMAZON      5.070007        5.070007       5.070007
#
# [1004 rows x 5 columns]

# %%
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2023-04-06  162.429993  164.960007  162.000000  164.660004  163.785767
# 1    2023-04-10  161.419998  162.029999  160.080002  162.029999  161.169724
# 2    2023-04-11  162.350006  162.360001  160.509995  160.800003  159.946243
# 3    2023-04-12  161.220001  162.059998  159.779999  160.100006  159.249985
# 4    2023-04-13  161.630005  165.800003  161.419998  165.559998  164.680984
# ...         ...         ...         ...         ...         ...         ...
# 999  2024-04-01  180.789993  183.000000  179.949997  180.970001  180.970001
# 1000 2024-04-02  179.070007  180.789993  178.380005  180.690002  180.690002
# 1001 2024-04-03  179.899994  182.869995  179.800003  182.410004  182.410004
# 1002 2024-04-04  184.000000  185.100006  180.000000  180.000000  180.000000
# 1003 2024-04-05  182.380005  186.270004  181.970001  185.070007  185.070007
#
# ...

# %%
selected_companies = ['APPLE', 'GOOGLE', 'MICROSOFT', 'AMAZON']
for company in selected_companies:
    company_data = df[df['company_name'] == company]
    plt.figure(figsize=(12, 6))
    plt.plot(company_data['Date'], company_data['Daily_Change'], label='Daily Change')
    plt.plot(company_data['Date'], company_data['Monthly_Change'], label='Monthly Change')
    plt.plot(company_data['Date'], company_data['Yearly_Change'], label='Yearly Change')
    plt.title(f'Change Over Time for {company}')
    plt.xlabel('Date')
    plt.ylabel('Change')
    plt.legend()
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# In 2023, we notice that the changes in stock prices vary from one company to another and from one period to another. This means that each company has its own way of operating and its own seasons, and we benefit from the fact that the average rate of change from year to year is relatively low.

# %% [markdown]
# ----

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2012-01-03   14.621429   14.732143   14.607143   14.686786   12.433825
# 2012-01-04   14.642857   14.810000   14.617143   14.765714   12.500646
# 2012-01-05   14.819643   14.948214   14.738214   14.929643   12.639432
# 2012-01-06   14.991786   15.098214   14.972143   15.085714   12.771554
# 2012-01-09   15.196429   15.276786   15.048214   15.061786   12.751299
# ...                ...         ...         ...         ...         ...
# 2024-04-01  171.190002  171.250000  169.479996  170.029999  170.029999
# 2024-04-02  169.080002  169.339996  168.229996  168.839996  168.839996
# 2024-04-03  168.789993  170.679993  168.580002  169.649994  169.649994
# 2024-04-04  170.289993  171.919998  168.820007  168.820007  168.820007
# 2024-04-05  169.589996  170.389999  168.949997  169.580002  169.580002
#
#                Volume
# Date
# 2012-01-03  302220800
# 2012-01-04  260022000
# 2012-01-05  271269600
# ...

# %%
plt.figure(figsize=(16,6))
plt.title('Close Price History', fontsize=20, fontweight='bold', color='blue')            
plt.plot(df['Close'], color='green', linestyle='-', linewidth=2)          
plt.xlabel('Date', fontsize=18, fontweight='bold', color='red')            
plt.ylabel('Close Price USD ($)', fontsize=18, fontweight='bold', color='red')            
plt.xticks(fontsize=14, fontweight='bold', rotation=45, color='purple')          
plt.yticks(fontsize=14, fontweight='bold', color='purple')                 
plt.grid(True, linestyle='--', alpha=0.7)    
plt.show()

# %%
data = df.filter(['Close'])
dataset = data.values
training_data_len = int(np.ceil(len(dataset) * .95))

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

train_data = scaled_data[0:int(training_data_len), :]
x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])

x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

from keras.models import Sequential
from keras.layers import Dense, LSTM
model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape=(x_train.shape[1], 1)))
model.add(LSTM(64, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(x_train, y_train, batch_size=1, epochs=1)

test_data = scaled_data[training_data_len - 60:, :]
x_test = []
y_test = dataset[training_data_len:, :]

for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])
    
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)
rmse = np.sqrt(np.mean(((predictions - y_test) ** 2)))

print('Root Mean Squared Error (RMSE):', rmse)
# Out:
# /Users/baker/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# 2870/2870 ━━━━━━━━━━━━━━━━━━━━ 63s 21ms/step - loss: 0.0030
# ...
